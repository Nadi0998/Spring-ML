# %% [markdown]
# Вариант №1.
# Для заданного набора данных проведите корреляционный анализ. В случае наличия пропусков в данных удалите строки или колонки, содержащие пропуски. Сделайте выводы о возможности построения моделей машинного обучения и о возможном вкладе признаков в модель.
# Dataset - boston

# %%
import numpy as np
import pandas as pd
from typing import Dict, Tuple
from scipy import stats
from sklearn.datasets import load_boston
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data_boston = load_boston()

# %%
data = pd.DataFrame(data_boston.data,columns=data_boston.feature_names)
data['target'] = pd.Series(data_boston.target)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS   ...    PTRATIO       B  LSTAT  target
# 0  0.00632  18.0   2.31   0.0   ...       15.3  396.90   4.98    24.0
# 1  0.02731   0.0   7.07   0.0   ...       17.8  396.90   9.14    21.6
# 2  0.02729   0.0   7.07   0.0   ...       17.8  392.83   4.03    34.7
# 3  0.03237   0.0   2.18   0.0   ...       18.7  394.63   2.94    33.4
# 4  0.06905   0.0   2.18   0.0   ...       18.7  396.90   5.33    36.2
#
# [5 rows x 14 columns]

# %%
fig, ax = plt.subplots(figsize=(15,7))
sns.heatmap(data.corr(method='pearson'), ax=ax, annot=True, fmt='.2f')

# %% [markdown]
# Из датасета в связи с малой корреляцией с целевым признаком можно удалить:
# TAX
# INDUS
# DIS
# LSTAT

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64
